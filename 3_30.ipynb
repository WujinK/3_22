# %%
import matplotlib.pyplot as plt
plt.plot([1,4,5,8])
# plot() 주어진 숫자 값을 연결해서 선으로 만들어줌
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = [2,4,6,8]
y = [1,3,5,7]
plt.plot(x,y)
plt.show()

# %%
x = range(0,50)
y = range(0,50)
plt.plot(x,y, "ms")
