# %%
import matplotlib.pyplot as plt
plt.plot([1,4,5,8])
# plot() 주어진 숫자 값을 연결해서 선으로 만들어줌
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = [2,4,6,8]
y = [1,3,5,7]
plt.plot(x,y)
plt.show()

# %%
x = range(0,50)
y = range(0,50)
plt.plot(x,y, "ms")

# %%
import matplotlib.pyplot as plt
# figure = 도화지라고 보기
fig = plt.figure()
# fig.add_subplot(행의 갯수, 열의 갯수, 위치값)
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
plt.show()

# %%
fig = plt.figure(constrained_layout = True)
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(2,2,2)
ax1.plot(x,y,"ro")
ax2.plot(x,y,"ro")
ax1.set_xlabel("time")
ax1.set_ylabel("qty")
plt.show()

# %%
plt.style.use("ggplot")
fig = plt.figure()
ax = fig.add_subplot(111)
x = [3,4]
y = [1,2]
ax.bar(x,y,tick_label, color= colors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\py_wj\3_30.ipynb Cell 7' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/py_wj/3_30.ipynb#ch0000006?line=3'>4</a> x = [3,4]
#       <a href='vscode-notebook-cell:/c%3A/py_wj/3_30.ipynb#ch0000006?line=4'>5</a> y = [1,2]
# ----> <a href='vscode-notebook-cell:/c%3A/py_wj/3_30.ipynb#ch0000006?line=5'>6</a> ax.bar(x,y,tick_label, color= colors)
#
# NameError: name 'tick_label' is not defined
